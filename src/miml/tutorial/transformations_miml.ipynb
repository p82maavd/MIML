# %% [markdown]
# <a href="https://colab.research.google.com/github/p82maavd/MIML/blob/main/src/miml/tutorial/transformations_miml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the library on enviroment
# !pip install mimllearning

from miml.data import load_dataset

# Load dataset from library
toy = load_dataset("toy.arff", from_library=True)
# Out:
# Collecting mimllearning
#   Downloading mimllearning-1.0.11-py3-none-any.whl (966 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 966.1/966.1 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: mimllearning
# Successfully installed mimllearning-1.0.11

# %% [markdown]
# # Original Dataset

# %%
toy.show_dataset()
# Out:
# +--------+------+------+------+----------+----------+----------+----------+
# |  bag1  |  f1  |  f2  |  f3  |  label1  |  label2  |  label3  |  label4  |
# +========+======+======+======+==========+==========+==========+==========+
# |   0    |  42  | -198 | -109 |    1     |    0     |    0     |    1     |
# +--------+------+------+------+----------+----------+----------+----------+
# |   1    | 41.9 | -191 | -142 |    1     |    0     |    0     |    1     |
# +--------+------+------+------+----------+----------+----------+----------+
# |   2    |  35  | 14.2 | 6.33 |    1     |    0     |    0     |    1     |
# +--------+------+------+------+----------+----------+----------+----------+
# +--------+-------+------+------+----------+----------+----------+----------+
# |  bag2  |  f1   |  f2  |  f3  |  label1  |  label2  |  label3  |  label4  |
# +========+=======+======+======+==========+==========+==========+==========+
# |   0    | 11.25 | -98  |  10  |    0     |    1     |    1     |    0     |
# +--------+-------+------+------+----------+----------+----------+----------+
# |   1    |  31   | 40.5 | 7.85 |    0     |    1     |    1     |    0     |
# +--------+-------+------+------+----------+----------+----------+----------+

# %% [markdown]
# # MIMLtoML Transformation

# %%
from miml.transformation import ArithmeticTransformation, GeometricTransformation, MinMaxTransformation

# Execute mimltoml transformations on loaded dataset

print("Arithmetic Transformation")
print("-------------------------")
ArithmeticTransformation().transform_dataset(toy).show_dataset()
print("Geometric Transformation")
print("-------------------------")
GeometricTransformation().transform_dataset(toy).show_dataset()
print("Min Max Transformation")
print("-------------------------")
MinMaxTransformation().transform_dataset(toy).show_dataset()
# Out:
# Arithmetic Transformation
# -------------------------
# +--------+---------+----------+----------+----------+----------+----------+----------+
# |  bag1  |   f1    |    f2    |    f3    |  label1  |  label2  |  label3  |  label4  |
# +========+=========+==========+==========+==========+==========+==========+==========+
# |   0    | 39.6333 | -124.933 | -81.5567 |    1     |    0     |    0     |    1     |
# +--------+---------+----------+----------+----------+----------+----------+----------+
# +--------+--------+--------+-------+----------+----------+----------+----------+
# |  bag2  |   f1   |   f2   |  f3   |  label1  |  label2  |  label3  |  label4  |
# +========+========+========+=======+==========+==========+==========+==========+
# |   0    | 21.125 | -28.75 | 8.925 |    0     |    1     |    1     |    0     |
# +--------+--------+--------+-------+----------+----------+----------+----------+
# Geometric Transformation
# -------------------------
# +--------+------+-------+---------+----------+----------+----------+----------+
# |  bag1  |  f1  |  f2   |   f3    |  label1  |  label2  |  label3  |  label4  |
# +========+======+=======+=========+==========+==========+==========+==========+
# |   0    | 38.5 | -91.9 | -67.835 |    1     |    0     |    0     |    1     |
# +--------+------+-------+---------+----------+----------+----------+----------+
# +--------+--------+--------+-------+----------+----------+----------+----------+
# |  bag2  |   f1   |   f2   |  f3   |  label1  |  label2  |  label3  |  label4  |
# +========+========+========+=======+==========+==========+==========+==========+
# |   0    | 21.125 | -28.75 | 8.925 |    0     |    1     |    1     |    0     |
# +--------+--------+--------+-------+----------+----------+----------+----------+
# Min Max Transformation
# -------------------------
# +--------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+
# |  bag1  |  min_f1  |  min_f2  |  min_f3  |  max_f1  |  max_f2  |  max_f3  |  label1  |  label2  |  label3  |  label4  |
# +========+==========+==========+==========+==========+==========+==========+==========+==========+==========+==========+
# |   0    |    35    |   -198   |   -142   |    42    |   14.2   |   6.33   |    1     |    0     |    0     |    1     |
# +--------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+
# +--------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+
# |  bag2  |  min_f1  |  min_f2  |  min_f3  |  max_f1  |  max_f2  |  max_f3  |  label1  |  label2  |  label3  |  label4  |
# +========+==========+==========+==========+==========+==========+==========+==========+==========+==========+==========+
# |   0    |  11.25   |   -98    |   7.85   |    31    |   40.5   |    10    |    0     |    1     |    1     |    0     |
# +--------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+

# %% [markdown]
# # MIMLtoMI Transformation

# %%
from miml.transformation import BinaryRelevanceTransformation, LabelPowersetTransformation

# Execute mimltomi transformations on loaded dataset

print("Label Powerset Transformation")
print("-----------------------------")

LabelPowersetTransformation().transform_dataset(dataset = toy).show_dataset()

print("Binary Relevance Transformation")
print("-------------------------------")

datasets = BinaryRelevanceTransformation().transform_dataset(dataset = toy)

for i, dataset in enumerate(datasets):
  print("Dataset of label", i+1)
  dataset.show_dataset()
# Out:
# Label Powerset Transformation
# -----------------------------
# +--------+------+------+------+------------+
# |  bag1  |  f1  |  f2  |  f3  |  lp label  |
# +========+======+======+======+============+
# |   0    |  42  | -198 | -109 |     9      |
# +--------+------+------+------+------------+
# |   1    | 41.9 | -191 | -142 |     9      |
# +--------+------+------+------+------------+
# |   2    |  35  | 14.2 | 6.33 |     9      |
# +--------+------+------+------+------------+
# +--------+-------+------+------+------------+
# |  bag2  |  f1   |  f2  |  f3  |  lp label  |
# +========+=======+======+======+============+
# |   0    | 11.25 | -98  |  10  |     6      |
# +--------+-------+------+------+------------+
# |   1    |  31   | 40.5 | 7.85 |     6      |
# +--------+-------+------+------+------------+
# Binary Relevance Transformation
# -------------------------------
# Dataset of label 1
# +--------+------+------+------+----------+
# |  bag1  |  f1  |  f2  |  f3  |  label1  |
# +========+======+======+======+==========+
# |   0    |  42  | -198 | -109 |    1     |
# +--------+------+------+------+----------+
# |   1    | 41.9 | -191 | -142 |    1     |
# +--------+------+------+------+----------+
# |   2    |  35  | 14.2 | 6.33 |    1     |
# +--------+------+------+------+----------+
# +--------+-------+------+------+----------+
# |  bag2  |  f1   |  f2  |  f3  |  label1  |
# +========+=======+======+======+==========+
# |   0    | 11.25 | -98  |  10  |    0     |
# +--------+-------+------+------+----------+
# |   1    |  31   | 40.5 | 7.85 |    0     |
# +--------+-------+------+------+----------+
# Dataset of label 2
# +--------+------+------+------+----------+
# |  bag1  |  f1  |  f2  |  f3  |  label2  |
# +========+======+======+======+==========+
# |   0    |  42  | -198 | -109 |    0     |
# +--------+------+------+------+----------+
# |   1    | 41.9 | -191 | -142 |    0     |
# +--------+------+------+------+----------+
# |   2    |  35  | 14.2 | 6.33 |    0     |
# +--------+------+------+------+----------+
# +--------+-------+------+------+----------+
# |  bag2  |  f1   |  f2  |  f3  |  label2  |
# +========+=======+======+======+==========+
# |   0    | 11.25 | -98  |  10  |    1     |
# +--------+-------+------+------+----------+
# |   1    |  31   | 40.5 | 7.85 |    1     |
# +--------+-------+------+------+----------+
# Dataset of label 3
# +--------+------+------+------+----------+
# |  bag1  |  f1  |  f2  |  f3  |  label3  |
# +========+======+======+======+==========+
# |   0    |  42  | -198 | -109 |    0     |
# +--------+------+------+------+----------+
# |   1    | 41.9 | -191 | -142 |    0     |
# +--------+------+------+------+----------+
# |   2    |  35  | 14.2 | 6.33 |    0     |
# +--------+------+------+------+----------+
# +--------+-------+------+------+----------+
# |  bag2  |  f1   |  f2  |  f3  |  label3  |
# +========+=======+======+======+==========+
# |   0    | 11.25 | -98  |  10  |    1     |
# +--------+-------+------+------+----------+
# |   1    |  31   | 40.5 | 7.85 |    1     |
# +--------+-------+------+------+----------+
# Dataset of label 4
# +--------+------+------+------+----------+
# |  bag1  |  f1  |  f2  |  f3  |  label4  |
# +========+======+======+======+==========+
# |   0    |  42  | -198 | -109 |    1     |
# +--------+------+------+------+----------+
# |   1    | 41.9 | -191 | -142 |    1     |
# +--------+------+------+------+----------+
# |   2    |  35  | 14.2 | 6.33 |    1     |
# +--------+------+------+------+----------+
# +--------+-------+------+------+----------+
# |  bag2  |  f1   |  f2  |  f3  |  label4  |
# +========+=======+======+======+==========+
# |   0    | 11.25 | -98  |  10  |    0     |
# +--------+-------+------+------+----------+
# |   1    |  31   | 40.5 | 7.85 |    0     |
# +--------+-------+------+------+----------+
